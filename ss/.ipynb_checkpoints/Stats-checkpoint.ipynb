# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
linex = np.linspace(1, 10, num=100)
liney = 0.32*(linex**(0.9))

ax = sns.scatterplot(x=linex, y=liney, s=5, c="c")
plt.xscale("log")

# %%
a = [1,	1,	2,	4,	3,	5,	19,	20,	20,	19,	21,	17, 10]
b = [1,	2,	4,	5,	7,	8,	13,	15,	17,	19,	20,	10, 10]
c = [1, 1,	2,	4,	3,	5,	6,	3,	20,	2,	21,	15, 13]
ab =  [[1,	1,	2,	4,	3,	18,	19,	20,	20,	19,	21,	17], [1, 2,	4,	5,	7,	8,	13,	15,	17,	19,	20,	10]]

sns.set(rc={"figure.figsize":(5, 2)})
sns.boxplot(x=c, boxprops=dict(alpha=.4), linewidth=1, showfliers= False)
sns.stripplot(x=c, orient="h")
print(sum(c)/len(c))
# Out:
# 7.384615384615385

# %%
sns.set(rc={"figure.figsize":(5, 2)})
sns.boxplot(x=b, boxprops=dict(alpha=.4), linewidth=1, showfliers= False, color="red")
sns.stripplot(x=b, orient="h", color="red")
# Out:
# <Axes: >

# %%
print(sum(a)/len(a))
print(sum(b)/len(b))
print(sum(c)/len(c))
# Out:
# 10.923076923076923
# 10.076923076923077
# 6.0
